# %% [markdown]
# #Write a python code to create the axis objects as shown below.

# %% [markdown]
# # (A)

# %%
import matplotlib.pyplot as plt
fig,(ax1,ax2)= plt.subplots(1,2, figsize=(10,4))
fig,row= plt.subplots(figsize=(10,4))

# %% [markdown]
# # (B)

# %%
fig7, f7_axs = plt.subplots(2,2,figsize=(10,6))
gs = f7_axs[0, 1].get_gridspec()
for ax in f7_axs[0:, -1]:
    ax.remove()
axbig = fig7.add_subplot(gs[0:, -1])
axbig.annotate('Big Axes \nGridSpec[0:, -1]', (0.1, 0.5)
               )
# Out:
# Text(0.1, 0.5, 'Big Axes \nGridSpec[0:, -1]')
