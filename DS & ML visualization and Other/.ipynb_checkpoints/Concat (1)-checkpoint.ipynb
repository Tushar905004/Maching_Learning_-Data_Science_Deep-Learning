# %%
import pandas as pd

# %% [markdown]
# Reading the CSV files

# %%
df1=pd.read_csv('india_weather.csv')
df2 = pd.read_csv('usa_weather.csv')

# %%
df1
# Out:
#          city  temp  humidity
# 0       Delhi    45        50
# 1     Kolkata    35        80
# 2     Chennai    36        82
# 3      Mumbai    32        87
# 4    Banglore    37        78
# 5   Hyderabad    42        45
# 6        Pune    29        70
# 7      Jaipur    43        40
# 8  Chandigarh    27        66

# %%
df2
# Out:
#             city  temp  humidity
# 0       New York    23        40
# 1        Chicago    34        66
# 2  San Francisco    22        78
# 3     Washington    45        56
# 4             LA    40        45
# 5         Boston    37        89
# 6         Austin    22        50
# 7      San Diego    20        42
# 8         Denver    40        82

# %% [markdown]
# joining them using concat

# %%
df = pd.concat([df1,df2]) # more than 2 dataframes can be concatenated together
df
# Out:
#             city  temp  humidity
# 0          Delhi    45        50
# 1        Kolkata    35        80
# 2        Chennai    36        82
# 3         Mumbai    32        87
# 4       Banglore    37        78
# 5      Hyderabad    42        45
# 6           Pune    29        70
# 7         Jaipur    43        40
# 8     Chandigarh    27        66
# 0       New York    23        40
# 1        Chicago    34        66
# 2  San Francisco    22        78
# 3     Washington    45        56
# 4             LA    40        45
# 5         Boston    37        89
# 6         Austin    22        50
# 7      San Diego    20        42
# 8         Denver    40        82

# %% [markdown]
# ignoring the index

# %%
df = pd.concat([df1,df2],ignore_index= True)
df
# Out:
#              city  temp  humidity
# 0           Delhi    45        50
# 1         Kolkata    35        80
# 2         Chennai    36        82
# 3          Mumbai    32        87
# 4        Banglore    37        78
# 5       Hyderabad    42        45
# 6            Pune    29        70
# 7          Jaipur    43        40
# 8      Chandigarh    27        66
# 9        New York    23        40
# 10        Chicago    34        66
# 11  San Francisco    22        78
# 12     Washington    45        56
# 13             LA    40        45
# 14         Boston    37        89
# 15         Austin    22        50
# 16      San Diego    20        42
# 17         Denver    40        82

# %% [markdown]
# Adding keys

# %%
df = pd.concat([df1,df2], keys=["india", "us"]) #won't work when ignore_index = True
df
# Out:
#                   city  temp  humidity
# india 0          Delhi    45        50
#       1        Kolkata    35        80
#       2        Chennai    36        82
#       3         Mumbai    32        87
#       4       Banglore    37        78
#       5      Hyderabad    42        45
#       6           Pune    29        70
#       7         Jaipur    43        40
#       8     Chandigarh    27        66
# us    0       New York    23        40
#       1        Chicago    34        66
#       2  San Francisco    22        78
#       3     Washington    45        56
#       4             LA    40        45
#       5         Boston    37        89
#       6         Austin    22        50
#       7      San Diego    20        42
#       8         Denver    40        82

# %%
df.loc["india"] #accessing the keys
# Out:
#          city  temp  humidity
# 0       Delhi    45        50
# 1     Kolkata    35        80
# 2     Chennai    36        82
# 3      Mumbai    32        87
# 4    Banglore    37        78
# 5   Hyderabad    42        45
# 6        Pune    29        70
# 7      Jaipur    43        40
# 8  Chandigarh    27        66

# %% [markdown]
# Column wise concatination

# %%
#making another dataframe
windspeed_df = pd.DataFrame({
    "city": ["Delhi","Kolkata","Chennai","Mumbai"],
    "windspeed": [7,12,10,7],
})
windspeed_df
# Out:
#       city  windspeed
# 0    Delhi          7
# 1  Kolkata         12
# 2  Chennai         10
# 3   Mumbai          7

# %%
df1

# %%
df = pd.concat([df1,windspeed_df],axis=1) #axis =1 means column wise concat, default value is 0
df
# Out:
#          city  temp  humidity     city  windspeed
# 0       Delhi    45        50    Delhi        7.0
# 1     Kolkata    35        80  Kolkata       12.0
# 2     Chennai    36        82  Chennai       10.0
# 3      Mumbai    32        87   Mumbai        7.0
# 4    Banglore    37        78      NaN        NaN
# 5   Hyderabad    42        45      NaN        NaN
# 6        Pune    29        70      NaN        NaN
# 7      Jaipur    43        40      NaN        NaN
# 8  Chandigarh    27        66      NaN        NaN

# %% [markdown]
# When data is not arranged sequentially

# %%
df1

# %%
windspeed_df2 = pd.DataFrame({
    "city": ["Delhi","Pune","Jaipur","Mumbai"],
    "windspeed": [7,12,10,7],
}
)
windspeed_df2
# Out:
#      city  windspeed
# 0   Delhi          7
# 1    Pune         12
# 2  Jaipur         10
# 3  Mumbai          7

# %%
df = pd.concat([df1,windspeed_df2],axis=1)
df #no proper sequence of data can be seen
# Out:
#          city  temp  humidity    city  windspeed
# 0       Delhi    45        50   Delhi        7.0
# 1     Kolkata    35        80    Pune       12.0
# 2     Chennai    36        82  Jaipur       10.0
# 3      Mumbai    32        87  Mumbai        7.0
# 4    Banglore    37        78     NaN        NaN
# 5   Hyderabad    42        45     NaN        NaN
# 6        Pune    29        70     NaN        NaN
# 7      Jaipur    43        40     NaN        NaN
# 8  Chandigarh    27        66     NaN        NaN

# %%
windspeed_df2 = pd.DataFrame({
    "city": ["Delhi","Pune","Jaipur","Mumbai"],
    "windspeed": [7,12,10,7],
}, index =[0,6,7,3]
)
windspeed_df2
# Out:
#      city  windspeed
# 0   Delhi          7
# 6    Pune         12
# 7  Jaipur         10
# 3  Mumbai          7

# %%
df = pd.concat([df1,windspeed_df2],axis=1)
df
# Out:
#          city  temp  humidity    city  windspeed
# 0       Delhi    45        50   Delhi        7.0
# 1     Kolkata    35        80     NaN        NaN
# 2     Chennai    36        82     NaN        NaN
# 3      Mumbai    32        87  Mumbai        7.0
# 4    Banglore    37        78     NaN        NaN
# 5   Hyderabad    42        45     NaN        NaN
# 6        Pune    29        70    Pune       12.0
# 7      Jaipur    43        40  Jaipur       10.0
# 8  Chandigarh    27        66     NaN        NaN

# %% [markdown]
# Concatinating a pandas series

# %%
st = pd.Series(["Delhi","West bengal","Tamil Nadu","Maharashtra","Karnataka","Andra Pradesh","Maharashtra","Rajasthan","Punjab"], name="State")
st
# Out:
# 0            Delhi
# 1      West bengal
# 2       Tamil Nadu
# 3      Maharashtra
# 4        Karnataka
# 5    Andra Pradesh
# 6      Maharashtra
# 7        Rajasthan
# 8           Punjab
# Name: State, dtype: object

# %%
df = pd.concat([df1,st],axis=1)
df
# Out:
#          city  temp  humidity          State
# 0       Delhi    45        50          Delhi
# 1     Kolkata    35        80    West bengal
# 2     Chennai    36        82     Tamil Nadu
# 3      Mumbai    32        87    Maharashtra
# 4    Banglore    37        78      Karnataka
# 5   Hyderabad    42        45  Andra Pradesh
# 6        Pune    29        70    Maharashtra
# 7      Jaipur    43        40      Rajasthan
# 8  Chandigarh    27        66         Punjab
